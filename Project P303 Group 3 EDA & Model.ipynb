# %%
import pandas as pd
import numpy as np

# %%
Company_stock_prices = pd.read_excel("/Users/azim/Desktop/data science/data/Company stock prices.xlsx")
Company_stock_prices
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-10-19  537.070007  541.799988  525.380005  530.719971  530.719971
# 1   2020-10-20  528.140015  533.780029  522.260010  525.419983  525.419983
# 2   2020-10-21  501.029999  506.850006  488.250000  489.049988  489.049988
# 3   2020-10-22  494.690002  495.140015  482.000000  485.230011  485.230011
# 4   2020-10-23  488.109985  490.059998  481.350006  488.279999  488.279999
# ..         ...         ...         ...         ...         ...         ...
# 748 2023-10-10  385.579987  388.700012  372.250000  373.320007  373.320007
# 749 2023-10-11  372.779999  377.809998  365.339996  365.929993  365.929993
# 750 2023-10-12  366.480011  368.829987  359.049988  361.200012  361.200012
# 751 2023-10-13  355.640015  358.929993  352.049988  355.679993  355.679993
# 752 2023-10-16  356.209991  363.079987  354.769989  360.820007  360.820007
#
#        Volume
# 0     7567500
# 1    10047200
# 2    17405700
# 3     6997900
# 4     4927900
# ..        ...
# 748   7288900
# 749   9151400
# 750   7376100
# 751   6312600
# 752   5119100
#
# [753 rows x 7 columns]

# %% [markdown]
# #### Display the first five rows of the dataset

# %%
Company_stock_prices.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-10-19  537.070007  541.799988  525.380005  530.719971  530.719971
# 1 2020-10-20  528.140015  533.780029  522.260010  525.419983  525.419983
# 2 2020-10-21  501.029999  506.850006  488.250000  489.049988  489.049988
# 3 2020-10-22  494.690002  495.140015  482.000000  485.230011  485.230011
# 4 2020-10-23  488.109985  490.059998  481.350006  488.279999  488.279999
#
#      Volume
# 0   7567500
# 1  10047200
# 2  17405700
# 3   6997900
# 4   4927900

# %% [markdown]
# #### EXPLORATORY DATA ANALYSIS (EDA)

# %%
Company_stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 753 entries, 0 to 752
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       753 non-null    datetime64[ns]
#  1   Open       753 non-null    float64
#  2   High       753 non-null    float64
#  3   Low        753 non-null    float64
#  4   Close      753 non-null    float64
#  5   Adj Close  753 non-null    float64
#  6   Volume     753 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 41.3 KB

# %%
Company_stock_prices.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  753.000000  753.000000  753.000000  753.000000  753.000000
# mean   414.903107  421.117954  408.519270  414.796653  414.796653
# std    135.039753  135.568500  134.016834  134.669664  134.669664
# min    163.960007  172.059998  162.710007  166.369995  166.369995
# 25%    311.570007  319.799988  308.850006  313.480011  313.480011
# 50%    418.399994  425.260010  411.880005  416.029999  416.029999
# 75%    519.900024  526.380005  513.789978  519.780029  519.780029
# max    692.349976  700.989990  686.090027  691.690002  691.690002
#
#              Volume
# count  7.530000e+02
# mean   7.060370e+06
# std    7.470407e+06
# min    1.144000e+06
# 25%    3.629200e+06
# 50%    5.277700e+06
# 75%    7.973300e+06
# max    1.333875e+08

# %% [markdown]
# #### Check for missing values

# %%
Company_stock_prices.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# #### Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# #### Line Plot
# - We can create a line plot of the closing stock prices over time using the matplotlib library.

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Date', y='Close', data=Company_stock_prices)
plt.title('Closing Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Stock Price')
plt.show()

# %% [markdown]
# # grid line for opening price over time

# %%
plt.figure(figsize=(12, 6))
plt.plot(Company_stock_prices['Date'], Company_stock_prices['Open'])
plt.title('Opening Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Opening Price')
plt.grid()
plt.show()

# %% [markdown]
# #### From the plot, we can see that the closing and opening stock prices have increased over time, with some fluctuations.

# %% [markdown]
# # Scatter plot of Open vs. Close prices

# %%
plt.figure(figsize=(10, 6))
plt.scatter(Company_stock_prices['Open'], Company_stock_prices['Close'], alpha=0.5)
plt.title('Scatter Plot: Open vs. Close Prices')
plt.xlabel('Open Price')
plt.ylabel('Close Price')
plt.grid()
plt.show()

# %% [markdown]
# #### The scatter plot of Open vs. Close prices shows a relatively strong positive correlation, suggesting that the closing price is often close to the opening price on the same day.

# %% [markdown]
# # Box Plot
# ### We can create a box plot of the closing stock prices by year using the seaborn library.

# %%
Company_stock_prices['year'] = Company_stock_prices['Date'].dt.year
sns.boxplot(x='year', y='Close', data=Company_stock_prices)
plt.title('Closing Stock Prices by Year')
plt.xlabel('Year')
plt.ylabel('Closing Stock Price')
plt.show()

# %% [markdown]
# - From the plot, we can see that the closing stock prices have generally increased over the years, with some outliers.

# %% [markdown]
# ### Box plots for High, Low, and Volume

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=Company_stock_prices[['High', 'Low', 'Volume']])
plt.title('Box Plots: High, Low, and Volume')
plt.grid()
plt.show()

# %% [markdown]
# #### The box plots for High, Low, and Volume provide insights into the spread and distribution of these variables.
# #### High and Low prices have varying levels of volatility, while Volume varies over time,

# %% [markdown]
# ### Box plots for High, Low, and Adj Close

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=Company_stock_prices[['High', 'Low', 'Adj Close']])
plt.title('Box Plots: High, Low, and Adj Close')
plt.grid()
plt.show()

# %% [markdown]
# #### The box plots for High, Low, and Adj Close provide insights into the spread and distribution of these variables. High and Low prices show varying levels of volatility, while Adj Close prices have a more stable distribution.

# %% [markdown]
# ## Heatmap
# - We can create a heatmap to visualize the correlation between the stock prices using the seaborn library.

# %%
corr = Company_stock_prices[['Open', 'High', 'Low', 'Close']].corr()
plt.figure(figsize=(15,7))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Between Stock Prices')
plt.show()

# %% [markdown]
# - From the heatmap, we can see that the opening and closing prices have a strong positive correlation, while the low and high prices have a weaker positive correlation.

# %% [markdown]
# - We can start by visualizing the distribution of the target variable, which in this case is the closing stock price. We can use a histogram to visualize the distribution.

# %% [markdown]
# ## Histogram

# %% [markdown]
# ### Histogram of Adj Close prices

# %%
plt.figure(figsize=(10, 6))
plt.hist(Company_stock_prices['Adj Close'], bins=50, edgecolor='k')
plt.title('Histogram: Adj Close Prices')
plt.xlabel('Adj Close Price')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %% [markdown]
# #### The histogram of Adj Close prices demonstrates the distribution of adjusted closing prices, and also showing that most of the prices are within a certain range.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(Company_stock_prices['Close'], kde=True)
plt.title('Distribution of Closing Stock Price')
plt.xlabel('Closing Stock Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### the histogram of the closing stock price allows us to understand the central tendencies and spread of closing prices, as well as the overall shape and characteristics of the distribution.

# %% [markdown]
# ## Histograms for 'High', 'Low', and 'Volume'

# %%
plt.figure(figsize=(12, 8))
plt.hist(Company_stock_prices['High'], bins=50, alpha=0.5, label='High', edgecolor='k')
plt.hist(Company_stock_prices['Low'], bins=50, alpha=0.5, label='Low', edgecolor='k')
#plt.hist(Company_stock_prices['Volume'], bins=50, alpha=0.5, label='Volume', edgecolor='k')
plt.title('Histograms: High, Low')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### The histograms for 'High' and 'Low' prices show the distribution of daily high and low prices. Both histograms have long tails on the right side, it indicating that there are occasional extreme price values.

# %%
plt.figure(figsize=(12, 8))
plt.hist(Company_stock_prices['Volume'], bins=50, alpha=0.5, label='Volume', edgecolor='k')
plt.title('Histograms: Volume')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### #The histogram for 'Volume' shows the distribution of daily trading volumes. It indicates that the majority of trading days have a relatively low volume, while there are occasional spikes in trading activity.

# %% [markdown]
# #### Line Chart

# %% [markdown]
# - To visualize the daily returns, we can create a line chart using the pandas library. The line chart will show the percentage change in price from one day to the next.

# %%
daily_returns = Company_stock_prices['Close'].pct_change()
plt.plot(daily_returns.index, daily_returns.values)
plt.title('Company stock prices Daily Returns')
plt.xlabel('Date')
plt.ylabel('Daily Return')
plt.show()

# %% [markdown]
# #### Combination Chart
# - We can use a combination chart to visualize the stock prices with the volume traded.

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='Date', y='Close', data=Company_stock_prices, color='b')
sns.lineplot(x='Date', y='Volume', data=Company_stock_prices, color='g', alpha=0.5)
plt.title('Company stock prices with Volume Traded')
plt.xlabel('Year')
plt.ylabel('Price/Volume')
plt.legend(['Closing Price', 'Volume'])
plt.show()

# %% [markdown]
# ## We can also use a histogram to visualize the daily returns.

# %%
plt.figure(figsize=(12,6))
sns.histplot(Company_stock_prices['Close'].pct_change().dropna(), bins=100, kde=True)
plt.title('Company stock prices Daily Returns')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ####date and close # grid line for closing price over time

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - Exploratory Data Analysis (EDA) is an essential step in data science projects, and it provides a better understanding of the underlying patterns and relationships in the data. Here we performed EDA on the Company stock prices dataset using Python.
#
# + We started by loading the dataset and exploring it to understand its structure and contents.
#
# - After that, we visualized the data using various charts, such as line plots, heat maps, and histograms. We visualized the stock prices, returns, and trading volumes of the Company stock pricescompanies over time.
#
# + Overall, the visualizations showed that the Company stock prices index has steadily grown over time, with some periods of volatility. The returns of individual companies have also varied, with some outperforming the index, and others underperforming. Additionally, we observed a correlation between the trading volumes and stock prices of the companies.
#
# - EDA provides valuable insights into the data, and the visualizations help to communicate these insights effectively. By performing EDA, we can identify trends, patterns, and relationships that may not be immediately apparent from the data. This knowledge can then be used to inform further analysis and decision-making.

# %% [markdown]
# ### Thank You!

# %%
Company_stock_prices
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-10-19  537.070007  541.799988  525.380005  530.719971  530.719971
# 1   2020-10-20  528.140015  533.780029  522.260010  525.419983  525.419983
# 2   2020-10-21  501.029999  506.850006  488.250000  489.049988  489.049988
# 3   2020-10-22  494.690002  495.140015  482.000000  485.230011  485.230011
# 4   2020-10-23  488.109985  490.059998  481.350006  488.279999  488.279999
# ..         ...         ...         ...         ...         ...         ...
# 748 2023-10-10  385.579987  388.700012  372.250000  373.320007  373.320007
# 749 2023-10-11  372.779999  377.809998  365.339996  365.929993  365.929993
# 750 2023-10-12  366.480011  368.829987  359.049988  361.200012  361.200012
# 751 2023-10-13  355.640015  358.929993  352.049988  355.679993  355.679993
# 752 2023-10-16  356.209991  363.079987  354.769989  360.820007  360.820007
#
#        Volume  year
# 0     7567500  2020
# 1    10047200  2020
# 2    17405700  2020
# 3     6997900  2020
# 4     4927900  2020
# ..        ...   ...
# 748   7288900  2023
# 749   9151400  2023
# 750   7376100  2023
# 751   6312600  2023
# 752   5119100  2023
#
# [753 rows x 8 columns]

# %%
Company_stock_prices = Company_stock_prices.set_index('Date')
Company_stock_prices
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-10-19  537.070007  541.799988  525.380005  530.719971  530.719971
# 2020-10-20  528.140015  533.780029  522.260010  525.419983  525.419983
# 2020-10-21  501.029999  506.850006  488.250000  489.049988  489.049988
# 2020-10-22  494.690002  495.140015  482.000000  485.230011  485.230011
# 2020-10-23  488.109985  490.059998  481.350006  488.279999  488.279999
# ...                ...         ...         ...         ...         ...
# 2023-10-10  385.579987  388.700012  372.250000  373.320007  373.320007
# 2023-10-11  372.779999  377.809998  365.339996  365.929993  365.929993
# 2023-10-12  366.480011  368.829987  359.049988  361.200012  361.200012
# 2023-10-13  355.640015  358.929993  352.049988  355.679993  355.679993
# 2023-10-16  356.209991  363.079987  354.769989  360.820007  360.820007
#
#               Volume  year
# Date
# 2020-10-19   7567500  2020
# 2020-10-20  10047200  2020
# 2020-10-21  17405700  2020
# 2020-10-22   6997900  2020
# 2020-10-23   4927900  2020
# ...              ...   ...
# 2023-10-10   7288900  2023
# 2023-10-11   9151400  2023
# 2023-10-12   7376100  2023
# 2023-10-13   6312600  2023
# 2023-10-16   5119100  2023
#
# [753 rows x 7 columns]

# %% [markdown]
# #### Creating dataframe which only includes date and close time

# %%
close_df=pd.DataFrame(Company_stock_prices['Close'])
close_df
# Out:
#                  Close
# Date
# 2020-10-19  530.719971
# 2020-10-20  525.419983
# 2020-10-21  489.049988
# 2020-10-22  485.230011
# 2020-10-23  488.279999
# ...                ...
# 2023-10-10  373.320007
# 2023-10-11  365.929993
# 2023-10-12  361.200012
# 2023-10-13  355.679993
# 2023-10-16  360.820007
#
# [753 rows x 1 columns]

# %%
print(close_df.shape)
# Out:
# (753, 1)

# %%
close_df=close_df.reset_index()

# %%
close_df
# Out:
#           Date       Close
# 0   2020-10-19  530.719971
# 1   2020-10-20  525.419983
# 2   2020-10-21  489.049988
# 3   2020-10-22  485.230011
# 4   2020-10-23  488.279999
# ..         ...         ...
# 748 2023-10-10  373.320007
# 749 2023-10-11  365.929993
# 750 2023-10-12  361.200012
# 751 2023-10-13  355.679993
# 752 2023-10-16  360.820007
#
# [753 rows x 2 columns]

# %% [markdown]
# #### Normalizing / scaling close value between 0 to 1
#
# - Normalizing or scaling the close values of a stock (or any numerical data) between 0 and 1 is a common preprocessing step in machine learning, especially for models sensitive to the scale of input features.
#
# + We can achieve this using a technique called Min-Max scaling.

# %%
from sklearn.preprocessing import MinMaxScaler
close_stock = close_df.copy()
del close_df['Date']
scaler=MinMaxScaler(feature_range=(0,1))
closedf=scaler.fit_transform(np.array(close_df).reshape(-1,1))
print(closedf.shape)
# Out:
# (753, 1)

# %%
closedf
# Out:
# array([[0.69357719],
#        [0.68348813],
#        [0.61425415],
#        [0.60698243],
#        [0.6127884 ],
#        [0.61271223],
#        [0.61402572],
#        [0.60890503],
#        [0.64311275],
#        [0.58891721],
#        [0.6048694 ],
#        [0.61077058],
#        [0.62929265],
#        [0.66129218],
#        [0.66313862],
#        [0.57894236],
#        [0.59748342],
#        [0.49640222],
#        [0.55349122],
#        [0.50085664],
#        [0.45539863],
#        [0.4640981 ],
#        [0.44873602],
#        [0.45145816],
#        [0.4692759 ],
#        [0.45667401],
#        [0.42819615],
#        [0.43820911],
#        [0.4589393 ],
#        [0.44108351],
#        [0.41936346],
#        [0.4281581 ],
#        [0.40167899],
#        [0.38279524],
#        [0.42575954],
#        [0.42722529],
#        [0.43430669],
#        [0.41854487],
#        [0.40672352],
#        [0.38395646],
#        [0.37188764],
#        [0.35005332],
#        [0.33387271],
#        [0.36629104],
#        [0.36244573],
#        [0.33113152],
#        [0.31340899],
#        [0.33766086],
#        [0.36389249],
#        [0.39029543],
#        [0.40780859],
#        [0.39636792],
#        [0.41222496],
#        [0.39617755],
#        [0.39849995],
#        [0.39495928],
#        [0.40383007],
#        [0.429167  ],
#        [0.40946471],
#        [0.39636792],
#        [0.3942359 ],
#        [0.42855784],
#        [0.40695195],
#        [0.38448947],
#        [0.37268712],
#        [0.36075156],
#        [0.34575117],
#        [0.33832713],
#        [0.3503769 ],
#        [0.33267343],
#        [0.32644862],
#        [0.34691233],
#        [0.11387346],
#        [0.09870175],
#        [0.09356204],
#        [0.08288283],
#        [0.06097236],
#        [0.04220284],
#        [0.06310441],
#        [0.04566741],
#        [0.0629902 ],
#        [0.06377065],
#        [0.07165156],
#        [0.04178408],
#        [0.02779259],
#        [0.01281126],
#        [0.02149168],
#        [0.        ],
#        [0.0151146 ],
#        [0.04048961],
#        [0.03833854],
#        [0.04604813],
#        [0.02059698],
#        [0.03257063],
#        [0.03803398],
#        [0.0401089 ],
#        [0.02659332],
#        [0.0408513 ],
#        [0.04764715],
#        [0.05486181],
#        [0.05914491],
#        [0.0505216 ],
#        [0.07370746],
#        [0.06207645],
#        [0.05857383],
#        [0.06137213],
#        [0.06940533],
#        [0.0502551 ],
#        [0.03154269],
#        [0.00631997],
#        [0.00222721],
#        [0.0261555 ],
#        [0.01328716],
#        [0.01739892],
#        [0.00864237],
#        [0.0238331 ],
#        [0.02920127],
#        [0.04660019],
#        [0.04334502],
#        [0.02518467],
#        [0.02282419],
#        [0.01618061],
#        [0.02585091],
#        [0.03713929],
#        [0.03367472],
#        [0.04359249],
#        [0.03923323],
#        [0.02088251],
#        [0.0153811 ],
#        [0.01939771],
#        [0.0160093 ],
#        [0.04328791],
#        [0.04673342],
#        [0.06712101],
#        [0.09531334],
#        [0.10947615],
#        [0.10292775],
#        [0.09925379],
#        [0.09049724],
#        [0.11493947],
#        [0.11354985],
#        [0.1114178 ],
#        [0.11391154],
#        [0.10479327],
#        [0.11490139],
#        [0.12095486],
#        [0.11499658],
#        [0.12776976],
#        [0.12101197],
#        [0.147986  ],
#        [0.14530191],
#        [0.15786569],
#        [0.15750401],
#        [0.15099369],
#        [0.14235132],
#        [0.15000381],
#        [0.14237038],
#        [0.1145397 ],
#        [0.11075156],
#        [0.12038378],
#        [0.12870251],
#        [0.10833397],
#        [0.11078964],
#        [0.10332749],
#        [0.10886698],
#        [0.12120231],
#        [0.11372117],
#        [0.09902536],
#        [0.31852969],
#        [0.29838955],
#        [0.3026346 ],
#        [0.30764108],
#        [0.30962079],
#        [0.29730448],
#        [0.29463945],
#        [0.3035864 ],
#        [0.31135307],
#        [0.30029315],
#        [0.28778647],
#        [0.29111778],
#        [0.29393513],
#        [0.29770428],
#        [0.31378968],
#        [0.31556007],
#        [0.32180388],
#        [0.33958352],
#        [0.33031299],
#        [0.32269858],
#        [0.31862484],
#        [0.33044619],
#        [0.39008606],
#        [0.37879766],
#        [0.37432424],
#        [0.36096092],
#        [0.37782686],
#        [0.36669078],
#        [0.40453439],
#        [0.43137519],
#        [0.43565829],
#        [0.45069673],
#        [0.44563314],
#        [0.45147722],
#        [0.44338691],
#        [0.4443006 ],
#        [0.46257519],
#        [0.48284853],
#        [0.49036778],
#        [0.51275415],
#        [0.52251958],
#        [0.53091447],
#        [0.50557754],
#        [0.51079345],
#        [0.49128153],
#        [0.48753143],
#        [0.49046294],
#        [0.47508186],
#        [0.47725194],
#        [0.50154191],
#        [0.49849614],
#        [0.52181526],
#        [0.5236237 ],
#        [0.53211375],
#        [0.51867433],
#        [0.51726568],
#        [0.52413765],
#        [0.52128225],
#        [0.52859208],
#        [0.54064191],
#        [0.5245184 ],
#        [0.54001369],
#        [0.58712782],
#        [0.59243889],
#        [0.51597124],
#        [0.49708749],
#        [0.49874362],
#        [0.49746824],
#        [0.48789312],
#        [0.46980891],
#        [0.4938133 ],
#        [0.5189218 ],
#        [0.51825553],
#        [0.50127544],
#        [0.5037501 ],
#        [0.50489227],
#        [0.52232927],
#        [0.51764637],
#        [0.49975252],
#        [0.50180845],
#        [0.48597047],
#        [0.4976205 ],
#        [0.48985383],
#        [0.47414912],
#        [0.45044925],
#        [0.45336176],
#        [0.46051932],
#        [0.46980891],
#        [0.49718265],
#        [0.45793039],
#        [0.47525318],
#        [0.47911749],
#        [0.50182744],
#        [0.51073634],
#        [0.50885174],
#        [0.52065409],
#        [0.53740576],
#        [0.53184728],
#        [0.52685985],
#        [0.52621257],
#        [0.53108579],
#        [0.51077439],
#        [0.46803851],
#        [0.44567119],
#        [0.43891343],
#        [0.43407827],
#        [0.43750479],
#        [0.41865908],
#        [0.41456635],
#        [0.40630473],
#        [0.41580368],
#        [0.40523872],
#        [0.40207873],
#        [0.39973728],
#        [0.40209778],
#        [0.40729458],
#        [0.40047971],
#        [0.40076524],
#        [0.39256072],
#        [0.40954087],
#        [0.41799287],
#        [0.39395037],
#        [0.37988273],
#        [0.37087873],
#        [0.36037081],
#        [0.37015535]])

# %%
training_size=int(len(closedf)*0.72)
test_size=len(closedf)-training_size
train_data,test_data=closedf[0:training_size,:],closedf[training_size:len(closedf),:1]

# %% [markdown]
# - Ratio for training and testing data is 86:14
# + The code segment successfully divides the dataset closedf into training and testing sets for further analysis or modeling. The training set contains 86% of the data, while the testing set comprises the remaining 14%. This split is essential for training a machine learning model on historical data and subsequently evaluating its performance on unseen data. The shapes of the resulting training and testing sets are printed for verification.

# %%
training_size,test_size
# Out:
# (542, 211)

# %%
train_data
# Out:
# array([[0.69357719],
#        [0.68348813],
#        [0.61425415],
#        [0.60698243],
#        [0.6127884 ],
#        [0.61271223],
#        [0.67164778],
#        [0.68400214],
#        [0.65565748],
#        [0.6652897 ],
#        [0.65080332],
#        [0.43997944],
#        [0.42027716],
#        [0.38081553],
#        [0.36802333],
#        [0.41942057],
#        [0.41496609],
#        [0.49640222],
#        [0.55349122],
#        [0.50085664],
#        [0.45539863],
#        [0.4640981 ],
#        [0.44873602],
#        [0.45145816],
#        [0.4692759 ],
#        [0.45667401],
#        [0.42819615],
#        [0.43820911],
#        [0.4589393 ],
#        [0.44108351],
#        [0.41936346],
#        [0.4281581 ],
#        [0.40167899],
#        [0.38279524],
#        [0.42575954],
#        [0.42722529],
#        [0.43430669],
#        [0.41854487],
#        [0.40672352],
#        [0.38395646],
#        [0.37188764],
#        [0.35005332],
#        [0.33387271],
#        [0.36629104],
#        [0.36244573],
#        [0.33113152],
#        [0.31340899],
#        [0.33766086],
#        [0.36389249],
#        [0.39029543],
#        [0.40780859],
#        [0.39636792],
#        [0.41222496],
#        [0.39617755],
#        [0.39849995],
#        [0.39495928],
#        [0.40383007],
#        [0.429167  ],
#        [0.40946471],
#        [0.39636792],
#        [0.3942359 ],
#        [0.42855784],
#        [0.40695195],
#        [0.38448947],
#        [0.37268712],
#        [0.36075156],
#        [0.34575117],
#        [0.33832713],
#        [0.3503769 ],
#        [0.33267343],
#        [0.32644862],
#        [0.34691233],
#        [0.11387346],
#        [0.09870175],
#        [0.09356204],
#        [0.08288283],
#        [0.06097236],
#        [0.04220284],
#        [0.06310441],
#        [0.04566741],
#        [0.0629902 ],
#        [0.06377065],
#        [0.07165156],
#        [0.04178408],
#        [0.02779259],
#        [0.01281126],
#        [0.02149168],
#        [0.        ],
#        [0.0151146 ],
#        [0.04048961],
#        [0.03833854],
#        [0.04604813],
#        [0.02059698],
#        [0.03257063],
#        [0.03803398],
#        [0.0401089 ],
#        [0.02659332],
#        [0.0408513 ],
#        [0.04764715],
#        [0.05486181],
#        [0.05914491],
#        [0.0505216 ],
#        [0.07370746],
#        [0.06207645],
#        [0.05857383],
#        [0.06137213],
#        [0.06940533],
#        [0.0502551 ],
#        [0.03154269],
#        [0.00631997],
#        [0.00222721],
#        [0.0261555 ],
#        [0.01328716],
#        [0.01739892],
#        [0.00864237],
#        [0.0238331 ],
#        [0.02920127],
#        [0.04660019],
#        [0.04334502],
#        [0.02518467],
#        [0.02282419],
#        [0.01618061],
#        [0.02585091],
#        [0.03713929],
#        [0.03367472],
#        [0.04359249],
#        [0.03923323],
#        [0.02088251],
#        [0.0153811 ],
#        [0.01939771],
#        [0.0160093 ],
#        [0.04328791],
#        [0.04673342],
#        [0.06712101],
#        [0.09531334],
#        [0.10947615],
#        [0.10292775],
#        [0.09925379],
#        [0.09049724],
#        [0.11493947],
#        [0.11354985],
#        [0.1114178 ],
#        [0.11391154],
#        [0.10479327],
#        [0.11490139],
#        [0.12095486],
#        [0.11499658],
#        [0.12776976],
#        [0.12101197],
#        [0.147986  ],
#        [0.14530191],
#        [0.15786569],
#        [0.15750401],
#        [0.15099369],
#        [0.14235132],
#        [0.15000381],
#        [0.14237038],
#        [0.1145397 ],
#        [0.32753369],
#        [0.34095411],
#        [0.34628417],
#        [0.34337166],
#        [0.33499583],
#        [0.32924692],
#        [0.3285997 ],
#        [0.32711489],
#        [0.31344705],
#        [0.34230565],
#        [0.32791443],
#        [0.31666414],
#        [0.31852969],
#        [0.29838955],
#        [0.3026346 ],
#        [0.30764108],
#        [0.30962079],
#        [0.29730448],
#        [0.29463945],
#        [0.3035864 ],
#        [0.31135307],
#        [0.30029315],
#        [0.28778647],
#        [0.29111778],
#        [0.29393513],
#        [0.29770428],
#        [0.31378968],
#        [0.31556007],
#        [0.32180388],
#        [0.33958352],
#        [0.33031299],
#        [0.32269858],
#        [0.31862484],
#        [0.33044619],
#        [0.39008606],
#        [0.37879766],
#        [0.37432424],
#        [0.36096092],
#        [0.37782686],
#        [0.36669078],
#        [0.40453439],
#        [0.43137519],
#        [0.43565829],
#        [0.45069673],
#        [0.44563314],
#        [0.45147722],
#        [0.44338691],
#        [0.4443006 ],
#        [0.46257519],
#        [0.48284853],
#        [0.49036778],
#        [0.51275415],
#        [0.52251958],
#        [0.53091447],
#        [0.50557754],
#        [0.51079345],
#        [0.49128153],
#        [0.48753143],
#        [0.49046294],
#        [0.47508186],
#        [0.47725194],
#        [0.50154191],
#        [0.49849614],
#        [0.52181526],
#        [0.5236237 ],
#        [0.53211375],
#        [0.51867433],
#        [0.51726568],
#        [0.52413765],
#        [0.52128225],
#        [0.52859208],
#        [0.54064191],
#        [0.5245184 ],
#        [0.54001369],
#        [0.58712782],
#        [0.59243889],
#        [0.51597124],
#        [0.49708749],
#        [0.49874362],
#        [0.49746824],
#        [0.48789312],
#        [0.46980891],
#        [0.4938133 ],
#        [0.5189218 ],
#        [0.51825553],
#        [0.50127544],
#        [0.5037501 ],
#        [0.50489227],
#        [0.52232927],
#        [0.51764637],
#        [0.49975252],
#        [0.50180845],
#        [0.48597047],
#        [0.4976205 ],
#        [0.48985383],
#        [0.47414912],
#        [0.45044925],
#        [0.45336176],
#        [0.46051932],
#        [0.46980891],
#        [0.49718265],
#        [0.45793039],
#        [0.47525318],
#        [0.47911749],
#        [0.50182744],
#        [0.51073634],
#        [0.50885174],
#        [0.52065409],
#        [0.53740576],
#        [0.53184728],
#        [0.52685985],
#        [0.52621257],
#        [0.53108579],
#        [0.51077439],
#        [0.46803851],
#        [0.44567119],
#        [0.43891343],
#        [0.43407827],
#        [0.43750479],
#        [0.41865908],
#        [0.41456635],
#        [0.40630473],
#        [0.41580368],
#        [0.40523872],
#        [0.40207873],
#        [0.39973728],
#        [0.40209778],
#        [0.40729458],
#        [0.40047971],
#        [0.40076524],
#        [0.39256072],
#        [0.40954087],
#        [0.41799287],
#        [0.39395037],
#        [0.37988273],
#        [0.37087873],
#        [0.36037081],
#        [0.37015535]])

# %% [markdown]
# #### Create new dataset according to requirement of time-series prediction

# %%
import numpy
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
time_step = 13
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train:  (528, 13)
# y_train:  (528,)
# X_test:  (197, 13)
# y_test (197,)

# %% [markdown]
# - This function essentially prepares data for training a time series forecasting model. It organizes the data into sequences of input features (dataX) and their corresponding target values (dataY). This format is suitable for training models like recurrent neural networks (RNNs) or other sequence-based models. The time_step parameter allows flexibility in choosing how many past data points should be considered when creating the sequences.
#
# + We have a well-structured dataset for training and testing a machine learning model. The training data consists of 633 samples with 13 features each, and the corresponding target values are stored in y_train. The testing data consists of 92 samples with the same 13 features, and the corresponding target values are stored in y_test. This setup is ready for training and evaluating a machine learning model on your data.

# %% [markdown]
# ### LONG SHORT TERM MEMORY (LSTM)
#
# - Reshape input to be [samples, time steps, features] which is required for LSTM

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print("X_train: ", X_train.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train:  (528, 13, 1)
# X_test:  (197, 13, 1)

# %% [markdown]
# This code is preparing the data for a time series prediction task, possibly for a neural network model, with 633 samples in the training set, each having 13 time steps and 1 feature per time step. Similarly, there are 92 samples in the test set with the same time step and feature configurations.

# %% [markdown]
# ### LSTM Model Structure

# %%
tf.keras.backend.clear_session()
model=Sequential()
model.add(LSTM(32,return_sequences=True,input_shape=(time_step,1)))
model.add(LSTM(32,return_sequences=True))
model.add(LSTM(32))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 13, 32)            4352
#
#  lstm_1 (LSTM)               (None, 13, 32)            8320
#
#  lstm_2 (LSTM)               (None, 32)                8320
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 21025 (82.13 KB)
# Trainable params: 21025 (82.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Output Summary

# %% [markdown]
# - The model consists of three LSTM layers and one Dense layer.
# + The first LSTM layer has 4352 parameters.
# - The second LSTM layer has 8320 parameters.
# + The third LSTM layer has 8320 parameters.
# - The Dense layer has 33 parameters.
# + Total trainable parameters are 21025.
# - Total non-trainable parameters are 0.

# %% [markdown]
# #### Conclusion

# %% [markdown]
# - This model is designed for sequential data processing, which is common in time series analysis.
# + It has a relatively moderate number of units in the LSTM layers (32 units each), which can capture complex temporal patterns.
# - The model uses mean squared error as the loss function, indicating it is likely used for regression tasks.
# + The Adam optimizer is employed for gradient descent during training, which is a popular choice for deep learning models.
# - The total number of trainable parameters (21025) indicates a moderately complex model that could be suitable for a variety of time series prediction tasks.

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=95,batch_size=32,verbose=1)
# Out:
# Epoch 1/95
# 17/17 [==============================] - 2s 38ms/step - loss: 0.1338 - val_loss: 0.0449
# Epoch 2/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0209 - val_loss: 0.0026
# Epoch 3/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0080 - val_loss: 0.0018
# Epoch 4/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0025
# Epoch 5/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0039 - val_loss: 0.0025
# Epoch 6/95
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 7/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 8/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 9/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 10/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0023
# Epoch 11/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 12/95
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 13/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 14/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 15/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 16/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 17/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 18/95
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 19/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 20/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 21/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 22/95
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0020
# Epoch 23/95
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0034 - val_loss: 0.0023
# Epoch 24/95
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 25/95
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0040 - val_loss: 0.0030
# Epoch 26/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 27/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 28/95
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 29/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 30/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 31/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 32/95
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 33/95
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 34/95
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 35/95
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 36/95
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 37/95
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 38/95
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 39/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 40/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 41/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 42/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 43/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 44/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 45/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 46/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 47/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 48/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 49/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 50/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 51/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 52/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 53/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 54/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 55/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 56/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 57/95
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 58/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 59/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 60/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0022 - val_loss: 0.0010
# Epoch 61/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 62/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 63/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 64/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 65/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 66/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 67/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0020 - val_loss: 9.3543e-04
# Epoch 68/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 69/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 70/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 71/95
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 9.4417e-04
# Epoch 72/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0019 - val_loss: 9.2150e-04
# Epoch 73/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 8.8110e-04
# Epoch 74/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 8.9613e-04
# Epoch 75/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 76/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 77/95
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 78/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 79/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 80/95
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 8.5869e-04
# Epoch 81/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 82/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 9.0592e-04
# Epoch 83/95
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0017 - val_loss: 8.1390e-04
# Epoch 84/95
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0017 - val_loss: 9.8148e-04
# Epoch 85/95
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 8.4768e-04
# Epoch 86/95
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0018 - val_loss: 7.9237e-04
# Epoch 87/95
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0018 - val_loss: 8.9941e-04
# Epoch 88/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 7.8394e-04
# Epoch 89/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0016 - val_loss: 8.9384e-04
# Epoch 90/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 8.4668e-04
# Epoch 91/95
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 92/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 9.8620e-04
# Epoch 93/95
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 7.2648e-04
# Epoch 94/95
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 7.7874e-04
# Epoch 95/95
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 8.4919e-04

# %% [markdown]
# - The training loss (loss) is decreasing, and the validation loss (val_loss) is also decreasing. This indicates that the model is not overfitting to the training data and is generalizing well to the validation data.

# %% [markdown]
# #### Lets Do the prediction and check performance metrics

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict.shape, test_predict.shape
# Out:
# 17/17 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# ((528, 1), (197, 1))

# %% [markdown]
# #### Transform back to original form

# %%
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
original_ytrain = scaler.inverse_transform(y_train.reshape(-1,1)) 
original_ytest = scaler.inverse_transform(y_test.reshape(-1,1))

# %% [markdown]
# #### Evaluation metrices RMSE, MSE and MAE
#
# - Root Mean Square Error (RMSE), Mean Square Error (MSE) and Mean absolute Error (MAE) are a standard way to measure the error of a model in predicting quantitative data.

# %% [markdown]
# #### Evaluation metrices RMSE and MAE

# %%
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
print("Train data RMSE: ", math.sqrt(mean_squared_error(original_ytrain,train_predict)))
print("Train data MSE: ", mean_squared_error(original_ytrain,train_predict))
print("Test data MAE: ", mean_absolute_error(original_ytrain,train_predict))
print("-------------------------------------------------------------------------------------")
print("Test data RMSE: ", math.sqrt(mean_squared_error(original_ytest,test_predict)))
print("Test data MSE: ", mean_squared_error(original_ytest,test_predict))
print("Test data MAE: ", mean_absolute_error(original_ytest,test_predict))
# Out:
# Train data RMSE:  23.61197455135326
# Train data MSE:  557.5253422137539
# Test data MAE:  16.798573966621177
# -------------------------------------------------------------------------------------
# Test data RMSE:  15.308248967553887
# Test data MSE:  234.34248645261462
# Test data MAE:  12.353227662912438

# %% [markdown]
# #### Explained variance regression score
#
# - The explained variance score explains the dispersion of errors of a given dataset, and the formula is written as follows: Here, and Var(y) is the variance of prediction errors and actual values respectively. Scores close to 1.0 are highly desired, indicating better squares of standard deviations of errors.

# %%
print("Train data explained variance regression score:", explained_variance_score(original_ytrain, train_predict))
print("Test data explained variance regression score:", explained_variance_score(original_ytest, test_predict))
# Out:
# Train data explained variance regression score: 0.9821509107718817
# Test data explained variance regression score: 0.909193666675382

# %% [markdown]
# #### R2 score for regression
#
# - R-squared (R2) is a statistical measure that represents the proportion of the variance for a dependent variable that's explained by an independent variable or variables in a regression model.
#
# + 1 = Best 0 or < 0 = worse

# %%
train_r2_lstm=r2_score(original_ytrain, train_predict)
test_r2_lstm=r2_score(original_ytest, test_predict)
print("Train data R2 score:", train_r2_lstm)
print("Test data R2 score:", test_r2_lstm)
# Out:
# Train data R2 score: 0.9763393209432024
# Test data R2 score: 0.8974866303333267

# %% [markdown]
# - The R2 score is a measure of how well the model's predictions match the actual values. It ranges from -1 to 1, where 1 indicates a perfect prediction, 0 indicates that the model is no better than simply predicting the mean of the target variable, and negative values suggest that the model performs worse than a simple mean-based predictor.

# %% [markdown]
# ### Plotting

# %%
import matplotlib.pyplot as plt

# Shift train predictions for plotting
train_predict_plot = np.empty_like(closedf)
train_predict_plot[:, :] = np.nan
train_predict_plot[time_step:len(train_predict) + time_step, :] = train_predict

# Shift test predictions for plotting
test_predict_plot = np.empty_like(closedf)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(train_predict) + (time_step * 2) + 1:len(closedf) - 1, :] = test_predict

# Plot baseline and predictions
plt.figure(figsize=(20, 10))
plt.plot(scaler.inverse_transform(closedf), label="Actual Stock Prices", color='blue')
plt.plot(train_predict_plot, label="Training Predictions", color='green')
plt.plot(test_predict_plot, label="Testing Predictions", color='red')
plt.xlabel("Time Steps")
plt.ylabel("Stock Price")
plt.title("Stock Price Prediction")
plt.legend()
plt.show()

# %% [markdown]
# #### CONCLUSION

# %% [markdown]
# - Data Preparation: we loaded and preprocessed the stock price data, setting the 'Date' column as the index. And we used a Min-Max scaler to normalize the closing prices, which is often required for training machine learning models.
#
# + Data Splitting: we split the normalized data into training and testing sets, with 86% of the data used for training and the remaining 14% for testing.
#
# - LSTM Model: we created a Long Short-Term Memory (LSTM) neural network model for time series forecasting. The model architecture consists of three LSTM layers and a dense output layer. we trained the model using the training data and validated it using the test data.
#
# + Model Evaluation: we evaluated the LSTM models performance using several metrics like Root Mean Squared Error (RMSE) for both the training and testing data., Mean Squared Error (MSE) for both datasets., Mean Absolute Error (MAE) for both datasets. These metrics help assess how well the model predicts stock prices.
# - Model Visualization: we visualized the models predictions alongside the actual stock prices for both the training and testing data. The visualizations allow you to compare the model's forecasts with the real stock prices.

# %%
len(X_train) , len(X_test)
# Out:
# (528, 197)

# %%
preds_input = test_data[198:]
preds_input.shape
# Out:
# (13, 1)

# %%
preds_input = preds_input.reshape(1, -1)

# %%
temp_input = list(preds_input)
len(temp_input)
# Out:
# 1

# %%
temp_input = temp_input[0].tolist()

# %%
len(temp_input)
# Out:
# 13

# %%
Thirty_days_output=[]
i=0

while(i<30):
    if(len(temp_input)>13):
        temp_input = temp_input[1:]
        preds_input=np.array(temp_input)
        preds_input=preds_input.reshape(1,-1)
    


    preds_input = preds_input.reshape(1, time_step,1)
    day_output = model.predict(preds_input, verbose=0)
    temp_input.extend(day_output[0].tolist()) # Put in inpu i,e original
    Thirty_days_output.extend(day_output.tolist()) #Put in 30 days array

    #print(f"Day-{i+1} input:\n\n{preds_input}\n\n")
    #print(f"Day-{i+1} output:\n\n{day_output}\n\n")
    i=i+1

# %%
Thirty_days_output
# Out:
# [[0.390094131231308],
#  [0.38641902804374695],
#  [0.38612237572669983],
#  [0.3879431188106537],
#  [0.39071768522262573],
#  [0.39404505491256714],
#  [0.3975154161453247],
#  [0.40147680044174194],
#  [0.4057289659976959],
#  [0.4097200334072113],
#  [0.4136687219142914],
#  [0.41764435172080994],
#  [0.42157959938049316],
#  [0.42579102516174316],
#  [0.4304018020629883],
#  [0.4349745810031891],
#  [0.4396020174026489],
#  [0.44433242082595825],
#  [0.44918185472488403],
#  [0.45415714383125305],
#  [0.4592588543891907],
#  [0.46449553966522217],
#  [0.4698737859725952],
#  [0.4753919541835785],
#  [0.4810536503791809],
#  [0.4868639409542084],
#  [0.49282634258270264],
#  [0.49894979596138],
#  [0.5052445530891418],
#  [0.5117136836051941]]

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
import matplotlib.pyplot as plt

# %%
len(closedf)
# Out:
# 753

# %%
# Create an array to store the last known sequence (last 13 days)
last_known_sequence = test_data[-time_step:]

# Initialize an array to store the predicted values
predicted_values = []

# Number of days to predict (e.g., 30 days)
num_days_to_predict = 30

for _ in range(num_days_to_predict):
    # Reshape the last_known_sequence to match the input shape of the model
    last_known_sequence = last_known_sequence.reshape(1, time_step, 1)
    
    # Predict the next day's value
    next_day_prediction = model.predict(last_known_sequence)
    
    # Store the prediction
    predicted_values.append(next_day_prediction[0, 0])
    
    # Update the last_known_sequence for the next iteration
    last_known_sequence = np.append(last_known_sequence[0, 1:], next_day_prediction).reshape(1, time_step, 1)

# Inverse transform the predicted values to the original scale
predicted_values = scaler.inverse_transform(np.array(predicted_values).reshape(-1, 1))

# Print the predicted values for the next 30 days
print("Predicted Stock Prices for the Next 30 Days:")
print(predicted_values)
last_date=close_df.index.max()
forecast_dates=pd.date_range(start='2023-10-17', end='2023-11-15')
# Out:
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 8ms/step
# Predicted Stock Prices for the Next 30 Days:
# [[371.29422]
#  [369.36362]
#  [369.2078 ]
#  [370.16428]
#  [371.62183]
#  [373.36975]
#  [375.1928 ]
#  [377.2738 ]
#  [379.50754]
#  [381.6041 ]
#  [383.67844]
#  [385.7669 ]
#  [387.8342 ]
#  [390.04654]
#  [392.46866]
#  [394.87082]
#  [397.30173]
#  [399.7867 ]
#  [402.3342 ]
#  [404.9478 ]
#  [407.62787]
#  [410.37878]
#  [413.2041 ]
#  [416.10287]
#  [419.0771 ]
#  [422.12933]
#  [425.26154]
#  [428.4783 ]
#  [431.78506]
#  [435.18344]]

# %%
# Plot the original data
plt.figure(figsize=(20, 10))
plt.plot(scaler.inverse_transform(closedf), label="Actual Stock Prices", color='blue')

# Plot the training predictions and leave gaps for the test set
plt.plot(np.arange(0, len(train_predict_plot), 1), train_predict_plot, label="Training Predictions", color='green')

# Plot the test predictions within the range of the test data
test_prediction_start = len(train_predict) + (time_step * 2) + 1
test_prediction_end = test_prediction_start + len(test_predict)
plt.plot(np.arange(test_prediction_start, test_prediction_end), test_predict_plot[test_prediction_start:test_prediction_end], label="Testing Predictions", color='red')

# Plot the predicted values for the next 30 days
next_30_days_range = np.arange(len(closedf) - 1 + 1, len(closedf) - 1 + num_days_to_predict + 1)
plt.plot(next_30_days_range, predicted_values, label="Predicted Stock Prices (Next 30 Days)", color='purple')

plt.xlabel("Time Steps")
plt.ylabel("Stock Price")
plt.title("Stock Price Prediction for Next 30 Days")
plt.legend()
plt.show()

# %%
import pickle

pickle.dump(model, open('model.pkl','wb'))

# %%
model.save('my_model.h5')  # Save the model in a '.h5' file
# Out:
# /Users/azim/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
forecast_df=pd.DataFrame({'Date': forecast_dates,'Close': predicted_values.flatten()})
print(forecast_df)
# Out:
#          Date       Close
# 0  2023-10-17  371.294220
# 1  2023-10-18  369.363617
# 2  2023-10-19  369.207794
# 3  2023-10-20  370.164276
# 4  2023-10-21  371.621826
# 5  2023-10-22  373.369751
# 6  2023-10-23  375.192810
# 7  2023-10-24  377.273804
# 8  2023-10-25  379.507538
# 9  2023-10-26  381.604095
# 10 2023-10-27  383.678436
# 11 2023-10-28  385.766907
# 12 2023-10-29  387.834198
# 13 2023-10-30  390.046539
# 14 2023-10-31  392.468658
# 15 2023-11-01  394.870819
# 16 2023-11-02  397.301727
# 17 2023-11-03  399.786713
# 18 2023-11-04  402.334198
# 19 2023-11-05  404.947815
# 20 2023-11-06  407.627869
# 21 2023-11-07  410.378784
# 22 2023-11-08  413.204102
# 23 2023-11-09  416.102875
# 24 2023-11-10  419.077087
# 25 2023-11-11  422.129333
# 26 2023-11-12  425.261536
# 27 2023-11-13  428.478302
# 28 2023-11-14  431.785065
# 29 2023-11-15  435.183441

# %%
merged_file=pd.concat([close_df,forecast_df],ignore_index=True)
merged_file
# Out:
#           Close       Date
# 0    530.719971        NaT
# 1    525.419983        NaT
# 2    489.049988        NaT
# 3    485.230011        NaT
# 4    488.279999        NaT
# ..          ...        ...
# 778  422.129333 2023-11-11
# 779  425.261536 2023-11-12
# 780  428.478302 2023-11-13
# 781  431.785065 2023-11-14
# 782  435.183441 2023-11-15
#
# [783 rows x 2 columns]

# %%
merged_file.to_csv('/Users/azim/Desktop/project/merged_file.csv')
